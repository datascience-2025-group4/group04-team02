# %% [markdown]
# ### Imports and config

# %%
import os
import requests
import pandas as pd

# %% [markdown]
# ### Create folder for Chotia numbered Influenza A PDB files

# %%
PDB_URL = "https://opig.stats.ox.ac.uk/webapps/sabdab-sabpred/sabdab/pdb/{}/?scheme=chothia"
PDB_DIR2 = os.path.abspath(os.path.join(os.getcwd(), "..", "data", "pdbs_influenza_cnf"))
CSV_FILENAME2 = "pdb_ids_influenza.csv"
os.makedirs(PDB_DIR2, exist_ok=True)

csv_path = os.path.join(os.path.dirname(__file__) if '__file__' in globals() else os.getcwd(), CSV_FILENAME2)
df = pd.read_csv(csv_path, header=None)

unique_pdb_ids = df[0].dropna().astype(str).str.strip()
unique_pdb_ids = unique_pdb_ids[unique_pdb_ids.str.match(r"^[A-Za-z0-9]{4}$")].tolist()

print(f"{len(unique_pdb_ids)} valid PDB-IDs loaded.")
print(f"File saved in: {PDB_DIR2}")
# Out:
# 100 valid PDB-IDs loaded.
# File saved in: c:\Users\082mi\Documents\GitHub\group04-team02\data\pdbs_influenza_cnf

# %% [markdown]
# ### Download function

# %%
def download_pdb(pdb_id):
    filename = os.path.join(PDB_DIR2, f"{pdb_id}.pdb")

    # Check if file already exists in folder - skip download
    if os.path.exists(filename) > 100:
        print(f"{pdb_id} already exists - download skipped.")
        return filename
    else: 
        print(f"{pdb_id} to be downloaded.")

    # Download files that are still missing
    url = PDB_URL.format(pdb_id)
    try: 
        response = requests.get(url, timeout=10)
        if response.status_code == 200 and len(response.content) > 100:
            with open(filename, "wb") as f: 
                f.write(response.content)
            print(f"{pdb_id} downloaded successfully.")
            return filename
        else:
            print(f"{pdb_id} could not be downloaded (invalid content or status code).")
            return None
    except requests.exceptions.RequestException as e:
        print(f"{pdb_id} download failed due to connection error: {e}")
        return None

# %% [markdown]
# ### Start downloads

# %%
print(f"Start Downloading {len(unique_pdb_ids)} PDB-Files...\n")

for i, pdb_id in enumerate(unique_pdb_ids, 1):
    print(f"[{i}/{len(unique_pdb_ids)}] {pdb_id}:", end=" ")
    download_pdb(pdb_id)

print("\nDone.")
# Out:
# Start Downloading 100 PDB-Files...
#
# [1/100] 8veb: 8veb exists but is too small – redownloading.
# 8veb downloaded successfully.
# [2/100] 8ved: 8ved exists but is too small – redownloading.
# 8ved downloaded successfully.
# [3/100] 9dpc: 9dpc exists but is too small – redownloading.
# 9dpc downloaded successfully.
# [4/100] 9dru: 9dru exists but is too small – redownloading.
# 9dru downloaded successfully.
# [5/100] 9ds1: 9ds1 exists but is too small – redownloading.
# 9ds1 downloaded successfully.
# [6/100] 9mer: 9mer exists but is too small – redownloading.
# 9mer downloaded successfully.
# [7/100] 9mev: 9mev exists but is too small – redownloading.
# 9mev downloaded successfully.
# [8/100] 9azr: 9azr exists but is too small – redownloading.
# 9azr downloaded successfully.
# [9/100] 9azt: 9azt exists but is too small – redownloading.
# 9azt downloaded successfully.
# [10/100] 9dm0: 9dm0 exists but is too small – redownloading.
# 9dm0 downloaded successfully.
# [11/100] 8zr4: 8zr4 exists but is too small – redownloading.
# 8zr4 downloaded successfully.
# [12/100] 9ekf: 9ekf exists but is too small – redownloading.
# 9ekf downloaded successfully.
# [13/100] 9dwe: 9dwe exists but is too small – redownloading.
# 9dwe downloaded successfully.
# [14/100] 8tx3: 8tx3 exists but is too small – redownloading.
# 8tx3 downloaded successfully.
# [15/100] 8txp: 8txp exists but is too small – redownloading.
# 8txp downloaded successfully.
# [16/100] 8ut3: 8ut3 exists but is too small – redownloading.
# 8ut3 downloaded successfully.
# [17/100] 8gat: 8gat exists but is too small – redownloading.
# 8gat downloaded successfully.
# [18/100] 8gav: 8gav exists but is too small – redownloading.
# 8gav downloaded successfully.
# [19/100] 8ez3: 8ez3 exists but is too small – redownloading.
# 8ez3 downloaded successfully.
# [20/100] 8ez7: 8ez7 exists but is too small – redownloading.
# 8ez7 downloaded successfully.
# [21/100] 8ez8: 8ez8 exists but is too small – redownloading.
# 8ez8 downloaded successfully.
# [22/100] 8tpa: 8tpa exists but is too small – redownloading.
# 8tpa downloaded successfully.
# [23/100] 8tp5: 8tp5 exists but is too small – redownloading.
# 8tp5 downloaded successfully.
# [24/100] 8tp7: 8tp7 exists but is too small – redownloading.
# 8tp7 downloaded successfully.
# [25/100] 8e6j: 8e6j exists but is too small – redownloading.
# 8e6j downloaded successfully.
# [26/100] 7trh: 7trh exists but is too small – redownloading.
# 7trh downloaded successfully.
# [27/100] 8dis: 8dis exists but is too small – redownloading.
# 8dis downloaded successfully.
# [28/100] 8g3m: 8g3m exists but is too small – redownloading.
# 8g3m downloaded successfully.
# [29/100] 8g3n: 8g3n exists but is too small – redownloading.
# 8g3n downloaded successfully.
# [30/100] 8g3p: 8g3p exists but is too small – redownloading.
# 8g3p downloaded successfully.
# [31/100] 8g3q: 8g3q exists but is too small – redownloading.
# 8g3q downloaded successfully.
# [32/100] 8g3r: 8g3r exists but is too small – redownloading.
# 8g3r downloaded successfully.
# [33/100] 8g3v: 8g3v exists but is too small – redownloading.
# 8g3v downloaded successfully.
# [34/100] 8g40: 8g40 exists but is too small – redownloading.
# 8g40 downloaded successfully.
# [35/100] 8d21: 8d21 exists but is too small – redownloading.
# 8d21 downloaded successfully.
# [36/100] 7wvg: 7wvg exists but is too small – redownloading.
# 7wvg downloaded successfully.
# [37/100] 8gv7: 8gv7 exists but is too small – redownloading.
# 8gv7 downloaded successfully.
# [38/100] 8diu: 8diu exists but is too small – redownloading.
# 8diu downloaded successfully.
# [39/100] 8dim: 8dim exists but is too small – redownloading.
# 8dim downloaded successfully.
# [40/100] 5w08: 5w08 exists but is too small – redownloading.
# 5w08 downloaded successfully.
# [41/100] 6q18: 6q18 exists but is too small – redownloading.
# 6q18 downloaded successfully.
# [42/100] 6pzw: 6pzw exists but is too small – redownloading.
# 6pzw downloaded successfully.
# [43/100] 4fp8: 4fp8 exists but is too small – redownloading.
# 4fp8 downloaded successfully.
# [44/100] 6wxl: 6wxl exists but is too small – redownloading.
# 6wxl downloaded successfully.
# [45/100] 4m5z: 4m5z exists but is too small – redownloading.
# 4m5z downloaded successfully.
# [46/100] 5k9q: 5k9q exists but is too small – redownloading.
# 5k9q downloaded successfully.
# [47/100] 6lxj: 6lxj exists but is too small – redownloading.
# 6lxj downloaded successfully.
# [48/100] 5xku: 5xku exists but is too small – redownloading.
# 5xku downloaded successfully.
# [49/100] 6iut: 6iut exists but is too small – redownloading.
# 6iut downloaded successfully.
# [50/100] 7k39: 7k39 exists but is too small – redownloading.
# 7k39 downloaded successfully.
# [51/100] 5dur: 5dur exists but is too small – redownloading.
# 5dur downloaded successfully.
# [52/100] 6e4x: 6e4x exists but is too small – redownloading.
# 6e4x downloaded successfully.
# [53/100] 5ugy: 5ugy exists but is too small – redownloading.
# 5ugy downloaded successfully.
# [54/100] 3lzf: 3lzf exists but is too small – redownloading.
# 3lzf downloaded successfully.
# [55/100] 6q0h: 6q0h exists but is too small – redownloading.
# 6q0h downloaded successfully.
# [56/100] 4yk4: 4yk4 exists but is too small – redownloading.
# 4yk4 downloaded successfully.
# [57/100] 6urm: 6urm exists but is too small – redownloading.
# 6urm downloaded successfully.
# [58/100] 6xq0: 6xq0 exists but is too small – redownloading.
# 6xq0 downloaded successfully.
# [59/100] 7l0l: 7l0l exists but is too small – redownloading.
# 7l0l downloaded successfully.
# [60/100] 5y2l: 5y2l exists but is too small – redownloading.
# 5y2l downloaded successfully.
# [61/100] 4hkx: 4hkx exists but is too small – redownloading.
# 4hkx downloaded successfully.
# [62/100] 6q0o: 6q0o exists but is too small – redownloading.
# 6q0o downloaded successfully.
# [63/100] 7k37: 7k37 exists but is too small – redownloading.
# 7k37 downloaded successfully.
# [64/100] 6ml8: 6ml8 exists but is too small – redownloading.
# 6ml8 downloaded successfully.
# [65/100] 4fqi: 4fqi exists but is too small – redownloading.
# 4fqi downloaded successfully.
# [66/100] 6pzf: 6pzf exists but is too small – redownloading.
# 6pzf downloaded successfully.
# [67/100] 6pze: 6pze exists but is too small – redownloading.
# 6pze downloaded successfully.
# [68/100] 4py8: 4py8 exists but is too small – redownloading.
# 4py8 downloaded successfully.
# [69/100] 6whk: 6whk exists but is too small – redownloading.
# 6whk downloaded successfully.
# [70/100] 6oc3: 6oc3 exists but is too small – redownloading.
# 6oc3 downloaded successfully.
# [71/100] 6q0i: 6q0i exists but is too small – redownloading.
# 6q0i downloaded successfully.
# [72/100] 5a3i: 5a3i exists but is too small – redownloading.
# 5a3i downloaded successfully.
# [73/100] 6a67: 6a67 exists but is too small – redownloading.
# 6a67 downloaded successfully.
# [74/100] 6uyn: 6uyn exists but is too small – redownloading.
# 6uyn downloaded successfully.
# [75/100] 6iuv: 6iuv exists but is too small – redownloading.
# 6iuv downloaded successfully.
# [76/100] 6p3r: 6p3r exists but is too small – redownloading.
# 6p3r downloaded successfully.
# [77/100] 5umn: 5umn exists but is too small – redownloading.
# 5umn downloaded successfully.
# [78/100] 4xnm: 4xnm exists but is too small – redownloading.
# 4xnm downloaded successfully.
# [79/100] 3sdy: 3sdy exists but is too small – redownloading.
# 3sdy downloaded successfully.
# [80/100] 6q20: 6q20 exists but is too small – redownloading.
# 6q20 downloaded successfully.
# [81/100] 6q0e: 6q0e exists but is too small – redownloading.
# 6q0e downloaded successfully.
# [82/100] 5kan: 5kan exists but is too small – redownloading.
# 5kan downloaded successfully.
# [83/100] 3gbm: 3gbm exists but is too small – redownloading.
# 3gbm downloaded successfully.
# [84/100] 4xrc: 4xrc exists but is too small – redownloading.
# 4xrc downloaded successfully.
# [85/100] 6xpx: 6xpx exists but is too small – redownloading.
# 6xpx downloaded successfully.
# [86/100] 6nz7: 6nz7 exists but is too small – redownloading.
# 6nz7 downloaded successfully.
# [87/100] 5k9k: 5k9k exists but is too small – redownloading.
# 5k9k downloaded successfully.
# [88/100] 4xnq: 4xnq exists but is too small – redownloading.
# 4xnq downloaded successfully.
# [89/100] 6ocb: 6ocb exists but is too small – redownloading.
# 6ocb downloaded successfully.
# [90/100] 4o58: 4o58 exists but is too small – redownloading.
# 4o58 downloaded successfully.
# [91/100] 6e3h: 6e3h exists but is too small – redownloading.
# 6e3h downloaded successfully.
# [92/100] 4r8w: 4r8w exists but is too small – redownloading.
# 4r8w downloaded successfully.
# [93/100] 5w0d: 5w0d exists but is too small – redownloading.
# 5w0d downloaded successfully.
# [94/100] 6e56: 6e56 exists but is too small – redownloading.
# 6e56 downloaded successfully.
# [95/100] 6q0l: 6q0l exists but is too small – redownloading.
# 6q0l downloaded successfully.
# [96/100] 5gjs: 5gjs exists but is too small – redownloading.
# 5gjs downloaded successfully.
# [97/100] 5vag: 5vag exists but is too small – redownloading.
# 5vag downloaded successfully.
# [98/100] 6lxi: 6lxi exists but is too small – redownloading.
# 6lxi downloaded successfully.
# [99/100] 5w6g: 5w6g exists but is too small – redownloading.
# 5w6g downloaded successfully.
# [100/100] 3gbn: 3gbn exists but is too small – redownloading.
# 3gbn downloaded successfully.
#
# Done.
