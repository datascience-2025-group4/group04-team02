# %% [markdown]
# ## pairwise alignment corona

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Matrix einlesen
df = pd.read_csv(r"C:\Users\clara\group04-team02\archive\cdr_h1_alignment_matrix.tsv", sep="\t", index_col=0)

# Heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df, cmap="viridis")
plt.title("Alignment Scores - CDR H1")
plt.xlabel("Antibody")
plt.ylabel("Antibody")
plt.tight_layout()
plt.show()

# %%
# 1. In Distanzen umwandeln (z.B. Max-Score - Score)
max_score = df.values.max()
distance_matrix = max_score - df

# 2. PCA auf Distanzen (nicht optimal, besser wäre MDS)
# Falls du PCA probierst:
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
components = pca.fit_transform(distance_matrix)

# 3. Plot
import seaborn as sns
import matplotlib.pyplot as plt

pca_df = pd.DataFrame(components, columns=["PC1", "PC2"], index=df.index)
plt.figure(figsize=(8,6))
sns.scatterplot(x="PC1", y="PC2", data=pca_df)
plt.title("PCA der CDR_H1 Distanzmatrix")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)")
plt.tight_layout()
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# Hier nehmen wir wieder Distanzen
linked = linkage(distance_matrix, method="average")

plt.figure(figsize=(12,6))
dendrogram(linked, labels=df.index, leaf_rotation=90)
plt.title("Hierarchisches Clustering der Antikörper (CDR_H1)")
plt.ylabel("Distanz")
plt.tight_layout()
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Nehmen wir an: linkage-Objekt heißt "linked"
# threshold=200 ist ein Beispiel, kann angepasst werden
cluster_labels = fcluster(linked, t=200, criterion='distance')

# Zu DataFrame
df_clusters = pd.DataFrame({
    'ID': df.index,
    'Cluster': cluster_labels
})

# %%
from sklearn.manifold import MDS
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster

# Clusterlabels berechnen
cluster_labels = fcluster(linked, t=200, criterion='distance')

# MDS
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
coords = mds.fit_transform(distance_matrix)

# DataFrame
mds_df = pd.DataFrame(coords, columns=["Dim1", "Dim2"])
mds_df["Cluster"] = cluster_labels
mds_df["ID"] = df.index
# Out:
# c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(

# %%
# 1) Alignment-Score-Matrix laden
df = pd.read_csv(r"C:\Users\clara\group04-team02\archive\cdr_h1_alignment_matrix.tsv", sep="\t", index_col=0)

# 2) Distanzmatrix definieren (max - score)
max_score = df.values.max()
distance_matrix = max_score - df.values

# 3) Diagonale explizit auf 0 setzen
np.fill_diagonal(distance_matrix, 0)

# 4) squareform() konvertieren
from scipy.spatial.distance import squareform
condensed_distances = squareform(distance_matrix)

# 5) linkage
from scipy.cluster.hierarchy import linkage, fcluster
linked = linkage(condensed_distances, method="ward")

# 6) Clusterlabels
cluster_labels = fcluster(linked, t=200, criterion='distance')

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt

# 1) Matrix laden
df = pd.read_csv(r"C:\Users\clara\group04-team02\archive\cdr_h1_alignment_matrix.tsv", sep="\t", index_col=0)

# 2) Distanzmatrix erstellen
max_score = df.values.max()
distance_matrix = max_score - df.values
np.fill_diagonal(distance_matrix, 0)

# 3) squareform konvertieren
condensed = squareform(distance_matrix)

# 4) linkage
linked = linkage(condensed, method="ward")

# 5) Clusterlabels
n_clusters = 5
cluster_labels = fcluster(linked, t=n_clusters, criterion="maxclust")

# 6) Dendrogramm
plt.figure(figsize=(20, 8))
dendrogram(
    linked,
    labels=df.index,
    leaf_rotation=90,
    leaf_font_size=8,
    color_threshold=None
)
plt.title("Hierarchisches Clustering der Antikörper (CDR_H1)")
plt.xlabel("Antikörper")
plt.ylabel("Distanz")
plt.tight_layout()
plt.show()

# 7) Heatmap nach Clusterlabels sortiert
# Zeilen/Spalten nach Cluster sortieren
sorted_indices = np.argsort(cluster_labels)
sorted_df = df.iloc[sorted_indices, :].iloc[:, sorted_indices]

plt.figure(figsize=(10, 10))
plt.imshow(sorted_df.values, cmap="viridis", aspect="auto")
plt.colorbar(label="Alignment Score")
plt.title("Heatmap der Alignment Scores (nach Clustern sortiert)")
plt.xlabel("Antikörper")
plt.ylabel("Antikörper")
plt.tight_layout()
plt.show()

# %%
for idx, label in enumerate(df.index):
    print(f"{label}: Cluster {cluster_labels[idx]}")
# Out:
# SARS_9cci: Cluster 3
# SARS_9ccj: Cluster 5
# SARS_9bj2: Cluster 4
# SARS_8z6r: Cluster 2
# SARS_8z6s: Cluster 2
# SARS_8z6t: Cluster 2
# SARS_8z6x: Cluster 2
# SARS_8v5v: Cluster 2
# SARS_9c44: Cluster 3
# SARS_8s6m: Cluster 3
# SARS_8wpw: Cluster 2
# SARS_9atm: Cluster 3
# SARS_9au1: Cluster 2
# SARS_8kdm: Cluster 3
# SARS_8keo: Cluster 3
# SARS_8kep: Cluster 3
# SARS_8ker: Cluster 3
# SARS_8sdh: Cluster 3
# SARS_8vcr: Cluster 5
# SARS_8yww: Cluster 3
# SARS_8q5y: Cluster 3
# SARS_8xse: Cluster 3
# SARS_8xsf: Cluster 3
# SARS_8xsi: Cluster 3
# SARS_8xsj: Cluster 3
# SARS_8y6a: Cluster 2
# SARS_8c0y: Cluster 4
# SARS_8qh0: Cluster 4
# SARS_8qh1: Cluster 4
# SARS_8hlc: Cluster 3
# SARS_8hld: Cluster 2
# SARS_8p5m: Cluster 3
# SARS_8v4f: Cluster 4
# SARS_8x0y: Cluster 5
# SARS_8c2r: Cluster 4
# SARS_8xi6: Cluster 2
# SARS_8khc: Cluster 3
# SARS_8vye: Cluster 3
# SARS_8r1c: Cluster 5
# SARS_8sdf: Cluster 2
# SARS_8sdg: Cluster 3
# SARS_8siq: Cluster 3
# SARS_8sit: Cluster 3
# SARS_8cin: Cluster 1
# SARS_8cbf: Cluster 1
# SARS_8hp9: Cluster 5
# SARS_8hpq: Cluster 5
# SARS_8hpv: Cluster 4
# SARS_8tm1: Cluster 5
# SARS_7y3o: Cluster 3
# SARS_8hpf: Cluster 5
# SARS_8hpu: Cluster 5
# SARS_8hq7: Cluster 4
# SARS_8hrd: Cluster 2
# SARS_8hws: Cluster 4
# SARS_8hwt: Cluster 4
# SARS_8hes: Cluster 3
# SARS_8hgl: Cluster 3
# SARS_8h7l: Cluster 3
# SARS_8gf2: Cluster 4
# SARS_8el2: Cluster 2
# SARS_7yd1: Cluster 5
# SARS_8cim: Cluster 1
# SARS_8e1g: Cluster 4
# SARS_8eoo: Cluster 5
# SARS_7xeg: Cluster 4
# SARS_7xei: Cluster 4
# SARS_8h07: Cluster 3
# Flu_6p3r: Cluster 3
# Flu_5umn: Cluster 1
# Flu_4xnm: Cluster 5
# Flu_3sdy: Cluster 2
# Flu_6q20: Cluster 3
# Flu_6q0e: Cluster 5
# Flu_5kan: Cluster 2
# Flu_3gbm: Cluster 1
# Flu_4xrc: Cluster 5
# Flu_6xpx: Cluster 3
# Flu_6nz7: Cluster 3
# Flu_5k9k: Cluster 5
# Flu_4xnq: Cluster 5
# Flu_6ocb: Cluster 5
# Flu_4o58: Cluster 1
# Flu_6e3h: Cluster 2
# Flu_4r8w: Cluster 2
# Flu_5w0d: Cluster 2
# Flu_6e56: Cluster 3
# Flu_6q0l: Cluster 5
# Flu_5gjs: Cluster 1
# Flu_5vag: Cluster 1
# Flu_6lxi: Cluster 1
# Flu_5w6g: Cluster 5
# Flu_3gbn: Cluster 1

# %%
cluster_df = pd.DataFrame({
    "PDB": df.index,
    "Cluster": cluster_labels
}).sort_values("Cluster")
print(cluster_df)
# Out:
#            PDB  Cluster
# 856   Flu_3gbn        1
# 854   Flu_6lxi        1
# 853   Flu_5vag        1
# 852   Flu_5gjs        1
# 846   Flu_4o58        1
# ..         ...      ...
# 45   SARS_8hp9        5
# 319  SARS_7xh8        5
# 306  SARS_7wph        5
# 837   Flu_6q0e        5
# 18   SARS_8vcr        5
#
# [857 rows x 2 columns]

# %%
print(cluster_df.query("Cluster == 1"))
# Out:
#            PDB  Cluster
# 856   Flu_3gbn        1
# 854   Flu_6lxi        1
# 853   Flu_5vag        1
# 852   Flu_5gjs        1
# 846   Flu_4o58        1
# ..         ...      ...
# 820   Flu_6ml8        1
# 282  SARS_7msq        1
# 288  SARS_7vyr        1
# 315  SARS_7kqe        1
# 299  SARS_7m3i        1
#
# [94 rows x 2 columns]

# %%
from sklearn.manifold import MDS

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
coords = mds.fit_transform(distance_matrix)

mds_df = pd.DataFrame(coords, columns=["Dim1", "Dim2"], index=df.index)

plt.figure(figsize=(8,6))
sns.scatterplot(x="Dim1", y="Dim2", data=mds_df)
plt.title("MDS der CDR_H1 Distanzen")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(

# %%
import pandas as pd
from Bio import pairwise2

# Lies deine Tabelle ein
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

# Wir nehmen z.B. die Spalte 'CDR_H1' zum pairwise Vergleichen
cdr_column = 'CDR_H1'

# Optional: Filtere leere oder fehlende Sequenzen raus
data = data[data[cdr_column].notnull()]

# Liste für Scores
scores = []

# Alle pairwise alignments innerhalb der CDR_H1-Spalte
for i in range(len(data)):
    for j in range(i+1, len(data)):
        seq1 = data.iloc[i][cdr_column]
        seq2 = data.iloc[j][cdr_column]
        
        if isinstance(seq1, str) and isinstance(seq2, str):
            alignments = pairwise2.align.globalxx(seq1, seq2)
            score = alignments[0][2]  # alignment score
            scores.append(score)
            
            # Hier wird der Score sofort in eine Datei geschrieben:
            with open('scores_CDR_H1.txt', 'a') as f:
                f.write(f"{i},{j},{score}\n")
# Out:
# c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from Bio import pairwise2
#       4 # Lies deine Tabelle ein
# ----> 5 data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')
#       7 # Wir nehmen z.B. die Spalte 'CDR_H1' zum pairwise Vergleichen
#       8 cdr_column = 'CDR_H1'
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sars_cov2_cdr_seq.tsv'

# %%
# %pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Matrix einlesen
df = pd.read_csv(r"C:\Users\clara\group04-team02\data cleanup\scores_CDR_H1.txt", index_col=0)

# 2. Falls gewünscht: symmetrische Matrix prüfen
# (nur zur Sicherheit, kann sonst weggelassen werden)
# assert np.allclose(df.values, df.values.T), "Matrix ist nicht symmetrisch"

# 3. PCA vorbereiten
# Hinweis: PCA braucht Samples als Zeilen und Features als Spalten
# Wir nehmen hier einfach die Matrixzeilen als Features (jede Sequenz = Sample)
X = df.values

# 4. PCA ausführen
pca = PCA(n_components=2)
components = pca.fit_transform(X)

# 5. Ergebnisse in DataFrame packen
pca_df = pd.DataFrame(components, columns=["PC1", "PC2"], index=df.index)

# 6. Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x="PC1", y="PC2", data=pca_df, s=70)

# IDs annotieren
for i, txt in enumerate(pca_df.index):
    plt.annotate(txt, (pca_df.iloc[i,0], pca_df.iloc[i,1]), fontsize=8)


plt.title("PCA der CDR_H1 Alignment Scores")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% Varianz)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% Varianz)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Matrix einlesen
df = pd.read_csv(r"C:\Users\clara\group04-team02\data cleanup\scores_CDR_H1.txt", index_col=0)

# 3. PCA vorbereiten
X = df.values

# 4. PCA ausführen
pca = PCA(n_components=2)
components = pca.fit_transform(X)

# 5. Ergebnisse in DataFrame
pca_df = pd.DataFrame(components, columns=["PC1", "PC2"], index=df.index)

# 6. Nur Punkte plotten (kein Text)
plt.figure(figsize=(8,6))
sns.scatterplot(
    x="PC1",
    y="PC2",
    data=pca_df,
    s=60,
    color="royalblue",
    edgecolor="black"
)

plt.title("PCA der CDR_H1 Alignment Scores")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% Varianz)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% Varianz)")
plt.tight_layout()
plt.show()

# %%
from sklearn.manifold import MDS
import pandas as pd

# D = Distanzmatrix (z.B. 1 - Ähnlichkeitsscores, falls nötig)
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
coords = mds.fit_transform(df.values)

# Ergebnis als DataFrame
mds_df = pd.DataFrame(coords, columns=["Dim1", "Dim2"], index=df.index)

# Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(mds_df["Dim1"], mds_df["Dim2"])

for i, txt in enumerate(mds_df.index):
    plt.annotate(txt, (mds_df.iloc[i,0], mds_df.iloc[i,1]), fontsize=8)

plt.title("MDS der CDR_H1 Distanzmatrix")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       4 # D = Distanzmatrix (z.B. 1 - Ähnlichkeitsscores, falls nötig)
#       5 mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
# ----> 6 coords = mds.fit_transform(df.values)
#       8 # Ergebnis als DataFrame
#       9 mds_df = pd.DataFrame(coords, columns=["Dim1", "Dim2"], index=df.index)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:699, in MDS.fit_transform(self, X, y, init)
#     696 elif self.dissimilarity == "euclidean":
#     697     self.dissimilarity_matrix_ = euclidean_distances(X)
# --> 699 self.embedding_, self.stress_, self.n_iter_ = smacof(
#     700     self.dissimilarity_matrix_,
#     701     metric=self.metric,
#     702     n_components=self.n_components,
#     703     init=init,
#     704     n_init=self._n_init,
#     705     n_jobs=self.n_jobs,
#     706     max_iter=self.max_iter,
#     707     verbose=self.verbose,
#     708     eps=self.eps,
#     709     random_state=self.random_state,
#     710     return_n_iter=True,
#     711     normalized_stress=self.normalized_stress,
#     712 )
#     714 return self.embedding_
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:387, in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter, normalized_stress)
#     385 if effective_n_jobs(n_jobs) == 1:
#     386     for it in range(n_init):
# --> 387         pos, stress, n_iter_ = _smacof_single(
#     388             dissimilarities,
#     389             metric=metric,
#     390             n_components=n_components,
#     391             init=init,
#     392             max_iter=max_iter,
#     393             verbose=verbose,
#     394             eps=eps,
#     395             random_state=random_state,
#     396             normalized_stress=normalized_stress,
#     397         )
#     398         if best_stress is None or stress < best_stress:
#     399             best_stress = stress
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\manifold\_mds.py:110, in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state, normalized_stress)
#      23 def _smacof_single(
#      24     dissimilarities,
#      25     metric=True,
#    (...)     32     normalized_stress=False,
#      33 ):
#      34     """Computes multidimensional scaling using SMACOF algorithm.
#      35
#      36     Parameters
#    (...)    108            Groenen P. Springer Series in Statistics (1997)
#     109     """
# --> 110     dissimilarities = check_symmetric(dissimilarities, raise_exception=True)
#     112     n_samples = dissimilarities.shape[0]
#     113     random_state = check_random_state(random_state)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\sklearn\utils\validation.py:1599, in check_symmetric(array, tol, raise_warning, raise_exception)
#    1555 """Make sure that array is 2D, square and symmetric.
#    1556
#    1557 If the array is not symmetric, then a symmetrized version is returned.
#    (...)   1596     with 6 stored elements and shape (3, 3)>
#    1597 """
#    1598 if (array.ndim != 2) or (array.shape[0] != array.shape[1]):
# -> 1599     raise ValueError(
#    1600         "array must be 2-dimensional and square. shape = {0}".format(array.shape)
#    1601     )
#    1603 if sp.issparse(array):
#    1604     diff = array - array.T
#
# ValueError: array must be 2-dimensional and square. shape = (40681, 2)

# %%
import numpy as np

scores = []

# Read the file and extract scores
cdr_column = 'CDR_H1'  # Use the same column name as before

with open(f'scores_{cdr_column}.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        score = float(parts[2])
        scores.append(score)

# Calculate average
if scores:
    average_score = np.mean(scores)
    print(f"Average alignment score for {cdr_column}: {average_score:.2f}")
else:
    print("No scores found.")
# Out:
# Average alignment score for CDR_H1: 3.72

# %%
import pandas as pd
import numpy as np
from Bio import pairwise2
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Load your table
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

cdr_column = 'CDR_H1'
data = data[data[cdr_column].notnull()]
data = data.reset_index(drop=True)  # reset indices after filtering

num_sequences = len(data)
# Initialize a similarity matrix
similarity_matrix = np.zeros((num_sequences, num_sequences))

# Compute pairwise alignment scores
for i in range(num_sequences):
    for j in range(i, num_sequences):
        seq1 = data.loc[i, cdr_column]
        seq2 = data.loc[j, cdr_column]
        if isinstance(seq1, str) and isinstance(seq2, str):
            alignments = pairwise2.align.globalxx(seq1, seq2)
            score = alignments[0][2]
            similarity_matrix[i, j] = score
            similarity_matrix[j, i] = score  # matrix is symmetric

# Now turn similarity into distance (simple way: max_score - score)
max_score = np.max(similarity_matrix)
distance_matrix = max_score - similarity_matrix

# Perform hierarchical clustering
linked = linkage(distance_matrix, 'single')  # you can also try 'complete', 'average', etc.

# Plot dendrogram
plt.figure(figsize=(12, 6))
dendrogram(linked, labels=data.index)
plt.title(f"Hierarchical clustering for {cdr_column}")
plt.show()

# %% [markdown]
# #### das ist ultra trash sorry

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

cdr_column = 'CDR_H1'
data = data[data[cdr_column].notnull()]
data = data.reset_index(drop=True)

# Extract sequence lengths
data['length'] = data[cdr_column].apply(len)

# You can also use other features later (e.g. AA composition etc.)

# Reshape into correct form for clustering
lengths = data['length'].values.reshape(-1, 1)

# Hierarchical clustering
linked = linkage(lengths, 'single')

plt.figure(figsize=(12, 6))
dendrogram(linked, labels=data.index)
plt.title(f"Clustering based on length of {cdr_column}")
plt.show()

# %%
import pandas as pd
from Bio import pairwise2

# Lies deine Tabelle ein
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

# Wir nehmen z.B. die Spalte 'CDR_H2' zum pairwise Vergleichen
cdr_column = 'CDR_H2'

# Optional: Filtere leere oder fehlende Sequenzen raus
data = data[data[cdr_column].notnull()]

# Liste für Scores
scores = []

# Alle pairwise alignments innerhalb der CDR_H2-Spalte
for i in range(len(data)):
    for j in range(i+1, len(data)):
        seq1 = data.iloc[i][cdr_column]
        seq2 = data.iloc[j][cdr_column]
        
        if isinstance(seq1, str) and isinstance(seq2, str):
            alignments = pairwise2.align.globalxx(seq1, seq2)
            score = alignments[0][2]  # alignment score
            scores.append(score)
            
            # Hier wird der Score sofort in eine Datei geschrieben:
            with open('scores_CDR_H2.txt', 'a') as f:
                f.write(f"{i},{j},{score}\n")
# Out:
# c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       2 from Bio import pairwise2
#       4 # Lies deine Tabelle ein
# ----> 5 data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')
#       7 # Wir nehmen z.B. die Spalte 'CDR_H2' zum pairwise Vergleichen
#       8 cdr_column = 'CDR_H2'
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sars_cov2_cdr_seq.tsv'

# %%
import numpy as np

scores = []

# Read the file and extract scores
cdr_column = 'CDR_H2'  # Use the same column name as before

with open(f'scores_{cdr_column}.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        score = float(parts[2])
        scores.append(score)

# Calculate average
if scores:
    average_score = np.mean(scores)
    print(f"Average alignment score for {cdr_column}: {average_score:.2f}")
else:
    print("No scores found.")
# Out:
# Average alignment score for CDR_H2: 2.24

# %%
import pandas as pd
from Bio import pairwise2

# Load your table
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

# Select the CDR column you want to analyze
cdr_column = 'CDR_H3'  # Now we analyze CDR_H3

# Filter out missing or empty sequences
data = data[data[cdr_column].notnull()]

# List to store alignment scores (optional)
scores = []

# Perform pairwise alignments within the CDR_H3 column
for i in range(len(data)):
    for j in range(i+1, len(data)):
        seq1 = data.iloc[i][cdr_column]
        seq2 = data.iloc[j][cdr_column]
        
        if isinstance(seq1, str) and isinstance(seq2, str):
            alignments = pairwise2.align.globalxx(seq1, seq2)
            score = alignments[0][2]  # alignment score
            scores.append(score)
            
            # Save the score directly into a file
            with open('scores_CDR_H3.txt', 'a') as f:
                f.write(f"{i},{j},{score}\n")

# %%
import numpy as np

scores = []

# Read the file and extract scores
cdr_column = 'CDR_H3'  # Use the same column name as before

with open(f'scores_{cdr_column}.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        score = float(parts[2])
        scores.append(score)

# Calculate average
if scores:
    average_score = np.mean(scores)
    print(f"Average alignment score for {cdr_column}: {average_score:.2f}")
else:
    print("No scores found.")
# Out:
# Average alignment score for CDR_H3: 4.56

# %% [markdown]
# #### normalization alignment scores

# %%
import pandas as pd

# Load your original sequences
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')
cdr_column = 'CDR_H1'
data = data[data[cdr_column].notnull()].reset_index(drop=True)

# Compute sequence lengths
data['seq_length'] = data[cdr_column].apply(len)

# Load the scores file
scores_df = pd.read_csv('scores_CDR_H1.txt', header=None, names=['i', 'j', 'score'])

# Normalize
def normalize(row):
    len_i = data.loc[row['i'], 'seq_length']
    len_j = data.loc[row['j'], 'seq_length']
    max_len = max(len_i, len_j)
    return row['score'] / max_len

scores_df['normalized_score'] = scores_df.apply(normalize, axis=1)

# Save normalized file for future fast use
scores_df.to_csv('normalized_scores_CDR_H1.txt', index=False)

# Quick summary
print(f"Mean normalized score: {scores_df['normalized_score'].mean()}")

# Optional: plot
import matplotlib.pyplot as plt

plt.hist(scores_df['normalized_score'], bins=20)
plt.title('Normalized scores for CDR_H1')
plt.xlabel('Normalized score')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mean normalized score: 0.5133656137898065

# %%
import pandas as pd

# Load your original sequences
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')
cdr_column = 'CDR_H2'
data = data[data[cdr_column].notnull()].reset_index(drop=True)

# Compute sequence lengths
data['seq_length'] = data[cdr_column].apply(len)

# Load the scores file
scores_df = pd.read_csv('scores_CDR_H2.txt', header=None, names=['i', 'j', 'score'])

# Normalize
def normalize(row):
    len_i = data.loc[row['i'], 'seq_length']
    len_j = data.loc[row['j'], 'seq_length']
    max_len = max(len_i, len_j)
    return row['score'] / max_len

scores_df['normalized_score'] = scores_df.apply(normalize, axis=1)

# Save normalized file for future fast use
scores_df.to_csv('normalized_scores_CDR_H2.txt', index=False)

# Quick summary
print(f"Mean normalized score: {scores_df['normalized_score'].mean()}")

# Optional: plot
import matplotlib.pyplot as plt

plt.hist(scores_df['normalized_score'], bins=20)
plt.title('Normalized scores for CDR_H2')
plt.xlabel('Normalized score')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mean normalized score: 0.3833336173648161

# %%
import pandas as pd
from Bio import pairwise2

data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')
cdr_column = 'CDR_H3'
data = data[data[cdr_column].notnull()]
scores = []

for i in range(len(data)):
    for j in range(i+1, len(data)):
        seq1 = data.iloc[i][cdr_column]
        seq2 = data.iloc[j][cdr_column]
        
        if isinstance(seq1, str) and isinstance(seq2, str):
            alignments = pairwise2.align.globalxx(seq1, seq2)
            score = alignments[0][2]  # raw score (number of matches)
            alignment_length = max(len(seq1), len(seq2))  # simple approximation
            normalized_score = score / alignment_length
            scores.append(normalized_score)
            
            with open('normalized_scores_CDR_H3.txt', 'a') as f:
                f.write(f"{i},{j},{normalized_score}\n")
# Out:
# Mean normalized score: 0.30362870106096745

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read normalized score files
h1 = pd.read_csv('normalized_scores_CDR_H1.txt')
h2 = pd.read_csv('normalized_scores_CDR_H2.txt')
h3 = pd.read_csv('normalized_scores_CDR_H3.txt')

# Add CDR type columns
h1['CDR'] = 'CDR_H1'
h2['CDR'] = 'CDR_H2'
h3['CDR'] = 'CDR_H3'

# Combine into one DataFrame
all_scores = pd.concat([h1, h2, h3])

# Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=all_scores, x='CDR', y='normalized_score', palette='Set2')

# Optional: fast scatterplot instead of heavy swarmplot
sns.stripplot(data=all_scores, x='CDR', y='normalized_score', 
              color=".25", alpha=0.3, jitter=0.2)

plt.title('Comparison of Normalized Pairwise Alignment Scores')
plt.ylabel('Normalized Score')
plt.xlabel('CDR Regions')
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_16524\1000445293.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=all_scores, x='CDR', y='normalized_score', palette='Set2')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the full table
data = pd.read_csv('sars_cov2_cdr_seq.tsv', sep='\t')

# Choose your CDR columns
cdr_columns = ['CDR_H1', 'CDR_H2', 'CDR_H3']

# Dictionary to store conservation profiles
conservation_profiles = {}

for cdr in cdr_columns:
    # Filter missing sequences
    cdr_data = data[data[cdr].notnull()].reset_index(drop=True)
    
    # Find the longest sequence length
    max_len = cdr_data[cdr].apply(len).max()
    
    # Pad sequences with gaps to equal length
    padded_seqs = cdr_data[cdr].apply(lambda x: x.ljust(max_len, '-'))
    
    # Build sequence matrix
    seq_matrix = np.array([list(seq) for seq in padded_seqs])
    
    # Compute conservation per position
    conservation = []
    for col in seq_matrix.T:
        unique, counts = np.unique(col, return_counts=True)
        most_common_freq = counts.max() / counts.sum()
        conservation.append(most_common_freq)
    
    conservation_profiles[cdr] = conservation

# ---------- Combined Conservation Plot ----------
plt.figure(figsize=(12, 6))

for cdr in cdr_columns:
    plt.plot(conservation_profiles[cdr], marker='o', label=cdr)

plt.title("Position-wise conservation for CDR_H1, CDR_H2, CDR_H3")
plt.xlabel("Position")
plt.ylabel("Conservation (%)")
plt.ylim(0, 1.05)
plt.legend()
plt.grid()
plt.show()


# ---------- Heatmap ----------
# We need to align the length (pad shorter CDRs with NaNs)
max_total_len = max(len(conservation_profiles[cdr]) for cdr in cdr_columns)

heatmap_data = pd.DataFrame({
    cdr: conservation_profiles[cdr] + [np.nan]*(max_total_len - len(conservation_profiles[cdr]))
    for cdr in cdr_columns
})

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data.T, cmap="YlGnBu", annot=True, fmt=".2f", cbar_kws={'label': 'Conservation'})
plt.title("Heatmap of Conservation per Position")
plt.xlabel("Position")
plt.ylabel("CDR")
plt.show()j

# %%
max_length = 15
heatmap_data = pd.DataFrame({
    cdr: (conservation_profiles[cdr][:max_length] + [np.nan]*(max_length - len(conservation_profiles[cdr])))
    for cdr in cdr_columns
})
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data.T, cmap="YlGnBu", annot=True, fmt=".2f", cbar_kws={'label': 'Conservation'})
plt.title("Heatmap of Conservation per Position")
plt.xlabel("Position")
plt.ylabel("CDR")
plt.show()

# %% [markdown]
# also weil es halt für längere CDRs weniger samples gibt, sind die daten nicht so biologisch relevant, versuche das zu fixen :))

# %%
import pandas as pd
from Bio import AlignIO, SeqIO
from Bio.Align.Applications import ClustalOmegaCommandline
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# === 1. Load your CDR_H3 sequences ===
data = pd.read_csv(r"C:\Users\clara\group04-team02\data cleanup\human_cdr_seq.tsv", sep='\t')
cdr_column = 'CDR_H3'
data = data[data[cdr_column].notnull()]
data = data.reset_index(drop=True)

# === 2. Write sequences to FASTA file ===
records = []
for i, seq in enumerate(data[cdr_column]):
    records.append(SeqRecord(Seq(seq), id=f"Seq{i}", description=""))

SeqIO.write(records, "cdr_h3_sequences.fasta", "fasta")

# === 3. Run Multiple Sequence Alignment (MSA) ===
# You need Clustal Omega installed locally for this step!
# (can be installed via conda or system package manager)

clustalomega_cline = ClustalOmegaCommandline(
    infile="cdr_h3_sequences.fasta", 
    outfile="aligned_cdr_h3.fasta", 
    verbose=True, 
    auto=True, 
    force=True
)
clustalomega_cline()

# === 4. Read aligned sequences ===
alignment = AlignIO.read("aligned_cdr_h3.fasta", "fasta")
alignment_length = alignment.get_alignment_length()

# === 5. Calculate conservation per column ===
conservation = []
for i in range(alignment_length):
    column = alignment[:, i]
    aa_counts = pd.Series(list(column)).value_counts()
    most_common_count = aa_counts.iloc[0]
    conservation_score = most_common_count / len(column)
    conservation.append(conservation_score)

# === 6. Plot heatmap ===
plt.figure(figsize=(16, 2))
sns.heatmap(
    np.array([conservation]), 
    cmap="YlGnBu", 
    cbar_kws={'label': 'Conservation'},
    xticklabels=range(1, alignment_length + 1),
    yticklabels=['CDR_H3']
)
plt.title("Conservation across aligned CDR_H3 sequences")
plt.xlabel("Aligned Position")
plt.ylabel("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# Cell In[4], line 35
#      24 # === 3. Run Multiple Sequence Alignment (MSA) ===
#      25 # You need Clustal Omega installed locally for this step!
#      26 # (can be installed via conda or system package manager)
#      28 clustalomega_cline = ClustalOmegaCommandline(
#      29     infile="cdr_h3_sequences.fasta",
#      30     outfile="aligned_cdr_h3.fasta",
#    (...)     33     force=True
#      34 )
# ---> 35 clustalomega_cline()
#      37 # === 4. Read aligned sequences ===
#      38 alignment = AlignIO.read("aligned_cdr_h3.fasta", "fasta")
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\Bio\Application\__init__.py:591, in AbstractCommandline.__call__(self, stdin, stdout, stderr, cwd, env)
#     588     stderr_arg.close()
#     590 if return_code:
# --> 591     raise ApplicationError(return_code, str(self), stdout_str, stderr_str)
#     592 return stdout_str, stderr_str
#
# ApplicationError: Non-zero return code 1 from 'clustalo -i cdr_h3_sequences.fasta -o aligned_cdr_h3.fasta --auto -v --force', message '"clustalo" no se reconoce como un comando interno o externo,'

# %% [markdown]
# #### hierchical clustering

# %%
# %pip install seaborn scipy
import seaborn as sns
import scipy.cluster.hierarchy as sch

sns.clustermap(df_matrix, cmap='viridis')
# Out:
# Requirement already satisfied: seaborn in c:\users\clara\anaconda3\envs\group2\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy in c:\users\clara\anaconda3\envs\group2\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\clara\anaconda3\envs\group2\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import seaborn as sns
#       3 import scipy.cluster.hierarchy as sch
# ----> 5 sns.clustermap(df_matrix, cmap='viridis')
#
# NameError: name 'df_matrix' is not defined

# %% [markdown]
# #### Dimensionality Reduction

# %%
from sklearn.manifold import MDS
import matplotlib.pyplot as plt

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
dissimilarity = 1 - (similarity_matrix / np.max(similarity_matrix))  # Abstand statt Ähnlichkeit
coords = mds.fit_transform(dissimilarity)

plt.scatter(coords[:, 0], coords[:, 1])
plt.title('MDS of CDR_H1 sequences')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn.manifold import MDS
#       2 import matplotlib.pyplot as plt
#       4 mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'
