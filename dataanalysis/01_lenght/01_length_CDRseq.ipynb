# %% [markdown]
# ## CDR amino acid sequence length

# %% [markdown]
# Analysis of CDR amino acid sequence lengths in antibody regions H1, H2, and H3 across coronavirus, human, and influenza.
#
# This Jupyter notebook aims to characterize the lengths of the CDR regions, compare differences between CDR H1, H2, and H3, and identify any variations among antibodies from coronavirus, human, and influenza sources.
# Therefore, the lengths of the CDR regions for each organism were first extracted. Additionally, correlations between the lengths of different regions were analyzed to assess whether, for example, a longer CDR H1 sequence is associated with a longer CDR H2 region.

# %% [markdown]
# ## Coronavirus

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# In this step, a dataset containing SARS-CoV-2 antibody CDR sequences was loaded from a TSV file (corona_cdr_seq.tsv). For each of the three CDR regions (CDR_H1, CDR_H2, and CDR_H3), the code computed the length of the amino acid sequence. Specifically, for every CDR column, a function was applied that determined the number of residues in the sequence if the value was a string; otherwise, a length of 0 was assigned.
# The resulting sequence lengths were stored in three new columns named len_H1, len_H2, and len_H3. Finally, these columns were printed to display the lengths of each CDR region for all records in the dataset.

# %%
data_corona = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\corona_cdr_seq.tsv", sep='\t')
for i in range(1,4):
    data_corona[f'len_H{i}'] = data_corona[f'CDR_H{i}'].apply(lambda x: len(x) if isinstance(x, str) else 0)
print(data_corona[['len_H1', 'len_H2', 'len_H3']])
# Out:
#      len_H1  len_H2  len_H3
# 0         7       6      16
# 1         9       5       9
# 2         7       6      21
# 3         7       6      19
# 4         7       6      12
# ..      ...     ...     ...
# 462       7       5       9
# 463       7       6      12
# 464       7       6      14
# 465       7       5      14
# 466       7       6      13
#
# [467 rows x 3 columns]

# %% [markdown]
# This code creates three scatter plots to visually compare the lengths of different CDR regions in the coronavirus antibody dataset:
# The first plot shows the relationship between the length of CDR_H1 and CDR_H2.
# The second plot compares the lengths of CDR_H2 and CDR_H3.
# The third plot compares the lengths of CDR_H1 and CDR_H3.
# Each plot uses transparency (alpha=0.5) to help visualize overlapping points better

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_corona['len_H1'], data_corona['len_H2'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H2')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H2')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_corona['len_H2'], data_corona['len_H3'], alpha=0.5)
plt.title('Length of CDR_H2 vs CDR_H3')
plt.xlabel('Length of CDR_H2')
plt.ylabel('Length of CDR_H3')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_corona['len_H1'], data_corona['len_H3'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H3')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H3')
plt.show()

# %% [markdown]
# # human CDRs

# %%
data_human = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\human_cdr_seq.tsv", sep='\t')
for i in range(1,4):
    data_human[f'len_H{i}'] = data_human[f'CDR_H{i}'].apply(lambda x: len(x) if isinstance(x, str) else 0)
print(data_human[['len_H1', 'len_H2', 'len_H3']])
# Out:
#      len_H1  len_H2  len_H3
# 0         9       5       8
# 1         9       5       8
# 2         7       6      16
# 3         7       6       8
# 4         7       6       8
# ..      ...     ...     ...
# 391       7       6      12
# 392       8       5      13
# 393       7       5      17
# 394       7       6      11
# 395       9       5      11
#
# [396 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_human['len_H1'], data_human['len_H2'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H2')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H2')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_human['len_H2'], data_human['len_H3'], alpha=0.5)
plt.title('Length of CDR_H2 vs CDR_H3')
plt.xlabel('Length of CDR_H2')
plt.ylabel('Length of CDR_H3')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_human['len_H1'], data_human['len_H3'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H3')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H3')
plt.show()

# %% [markdown]
# # influenza CDR

# %%
data_influenza = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\influenza_cdr_seq.tsv", sep='\t')
for i in range(1,4):
    data_influenza[f'len_H{i}'] = data_influenza[f'CDR_H{i}'].apply(lambda x: len(x) if isinstance(x, str) else 0)
print(data_influenza[['len_H1', 'len_H2', 'len_H3']])
# Out:
#     len_H1  len_H2  len_H3
# 0        9       5      21
# 1        7       5      19
# 2        9       5      21
# 3        9       5      21
# 4        7       6      17
# ..     ...     ...     ...
# 93       4       6      16
# 94       7       6      12
# 95       7       6      14
# 96       7       6      23
# 97       9       5      15
#
# [98 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_influenza['len_H1'], data_influenza['len_H2'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H2')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H2')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_influenza['len_H2'], data_influenza['len_H3'], alpha=0.5)
plt.title('Length of CDR_H2 vs CDR_H3')
plt.xlabel('Length of CDR_H2')
plt.ylabel('Length of CDR_H3')
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(data_influenza['len_H1'], data_influenza['len_H3'], alpha=0.5)
plt.title('Length of CDR_H1 vs CDR_H3')
plt.xlabel('Length of CDR_H1')
plt.ylabel('Length of CDR_H3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 20
#      18 plt.xlabel('Length of CDR_H1')
#      19 plt.ylabel('Length of CDR_H3')
# ---> 20 plt.show()
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)    611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
# -> 2158         bbox_inches = self.figure.get_tightbbox(
#    2159             renderer, bbox_extra_artists=bbox_extra_artists)
#    2160         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2161                 pad_inches == "layout"):
#    2162             h_pad = layout_engine.get()["h_pad"]
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\figure.py:1848, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1844 if ax.get_visible():
#    1845     # some Axes don't take the bbox_extra_artists kwarg so we
#    1846     # need this conditional....
#    1847     try:
# -> 1848         bbox = ax.get_tightbbox(
#    1849             renderer, bbox_extra_artists=bbox_extra_artists)
#    1850     except TypeError:
#    1851         bbox = ax.get_tightbbox(renderer)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\axes\_base.py:4522, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4520         if ba:
#    4521             bb.append(ba)
# -> 4522 self._update_title_position(renderer)
#    4523 axbbox = self.get_window_extent(renderer)
#    4524 bb.append(axbbox)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\axes\_base.py:3089, in _AxesBase._update_title_position(self, renderer)
#    3087 if title.get_text():
#    3088     for ax in axs:
# -> 3089         ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3090         if ax.yaxis.offsetText.get_text():
#    3091             bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\axis.py:1367, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1364 self._update_label_position(renderer)
#    1366 # go back to just this axis's tick labels
# -> 1367 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1369 self._update_offset_text_position(tlb1, tlb2)
#    1370 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\axis.py:1343, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1341 if renderer is None:
#    1342     renderer = self.get_figure(root=True)._get_renderer()
# -> 1343 return ([tick.label1.get_window_extent(renderer)
#    1344          for tick in ticks if tick.label1.get_visible()],
#    1345         [tick.label2.get_window_extent(renderer)
#    1346          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\text.py:365, in Text._get_layout(self, renderer)
#     359 """
#     360 Return the extent (bbox) of the text together with
#     361 multiple-alignment information. Note that it returns an extent
#     362 of a rotated text when necessary.
#     363 """
#     364 thisx, thisy = 0.0, 0.0
# --> 365 lines = self._get_wrapped_text().split("\n")  # Ensures lines is not empty.
#     367 ws = []
#     368 hs = []
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\text.py:693, in Text._get_wrapped_text(self)
#     688 """
#     689 Return a copy of the text string with new lines added so that the text
#     690 is wrapped relative to the parent figure (if `get_wrap` is True).
#     691 """
#     692 if not self.get_wrap():
# --> 693     return self.get_text()
#     695 # Not fit to handle breaking up latex syntax correctly, so
#     696 # ignore latex for now.
#     697 if self.get_usetex():
#
# File c:\Users\clara\anaconda3\envs\group2\Lib\site-packages\matplotlib\text.py:915, in Text.get_text(self)
#     911     # This should return the same data (possible unitized) as was
#     912     # specified with 'set_x' and 'set_y'.
#     913     return self._x, self._y
# --> 915 def get_text(self):
#     916     """Return the text string."""
#     917     return self._text
#
# KeyboardInterrupt:

# %% [markdown]
# This code calculates the Spearman correlation coefficients between the lengths of the three CDR regions within each dataset separately (SARS-CoV-2, Human, and Influenza). For each organism, it computes the correlation matrix showing how strongly the lengths of CDR H1, H2, and H3 are related. The heatmaps then display these correlations, making it easy to compare patterns between the datasets and see whether certain CDR lengths tend to vary together.
# The Spearman method was used instead of the Pearson method, since it is less sensitive to outliers and usually used when the values are not normally distributed.

# %%
datasets = {
    "SARS-CoV-2": data_corona,
    "Human": data_human,
    "Influenza": data_influenza
}

plt.figure(figsize=(15, 5))

for i, (name, df) in enumerate(datasets.items(), 1):
   
    len_cols = [f'len_H{i}' for i in range(1, 4)]
    corr = df[len_cols].corr(method="spearman")

    
    plt.subplot(1, 3, i)
    sns.heatmap(
        corr, 
        annot=True, 
        vmin=-1, vmax=1,
        cmap="coolwarm",
        square=True,
        cbar=False
    )
    plt.title(f"correlation of CDR-lengths\n{name}")

plt.tight_layout()
plt.show()

# %% [markdown]
# These heatmap do not show an instant correlation among CDR lengths, however a moderate negative correlation between the lengths of the CDR H1 and CDR H2 regions (r ≈ -0.3 to -0.5) is noticeable. This indicates a tendency among the three organsims, but not a strict inverse correlation.
# Additionally, CDR H2 and H3 are moderately correlated in SARS-CoV-2, nevertheless this trait is not present in Human and Influenza CDRs.

# %% [markdown]
# # Comparing SARS-CoV-2, Homo Sapiens and Influenza A

# %% [markdown]
# The aim in this is to visualize the distribution of lengths of each CDR (CDR_H1, CDR_H2, CDR_H3) per organism in collumns. For each CDR region, it creates a histogram comparing the length distributions of antibodies targeting SARS-CoV-2, humans, and Influenza A. Each group is visualized in a distinct color to easily compare how CDR lengths vary between organisms.

# %%
# Make sure all length columns exist:
for df in [data_corona, data_human, data_influenza]:
    for i in range(1, 4):
        col = f'len_H{i}'
        if col not in df.columns:
            df[col] = df[f'CDR_H{i}'].apply(lambda x: len(x) if isinstance(x, str) else 0)

# Define colors
palette = {
    'SARS-CoV-2': '#9509BB',
    'Homo Sapiens': '#FFCF01',
    'Influenza A': '#FF474B'
}

# CDRs
cdrs = ['len_H1', 'len_H2', 'len_H3']

# Plot a histogram for each CDR length
for cdr in cdrs:
    plt.figure(figsize=(10, 6))
    max_len = max(
        data_corona[cdr].max(),
        data_human[cdr].max(),
        data_influenza[cdr].max()
    )
    bins = range(0, max_len + 2)

    plt.hist(
        data_corona[cdr], bins=bins,
        alpha=0.5, label='SARS-CoV-2', color=palette['SARS-CoV-2'], edgecolor='black'
    )
    plt.hist(
        data_human[cdr], bins=bins,
        alpha=0.5, label='Homo Sapiens', color=palette['Homo Sapiens'], edgecolor='black'
    )
    plt.hist(
        data_influenza[cdr], bins=bins,
        alpha=0.5, label='Influenza A', color=palette['Influenza A'], edgecolor='black'
    )

    plt.title(f'Length Distribution of {cdr}')
    plt.xlabel('CDR Length')
    plt.ylabel('Frequency')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# This code creates a boxplot that compares the length distributions of different CDR regions across datasets. Each dataset—SARS-CoV-2, human, and influenza. Compared to the previous step, where the distribution was shown on a histogram, the advantage of a boxplot is that one recognizes more easily differences in distribution and length, with clear and direct comparison to other organsim or CDR region.
# The first step to create a grouped boxplot, is to combine all the data in a single table, where each row contains information with CDR region, which dataset it comes from (SARS-CoV-2, Human, or Influenza), and its length.
#
# This reshaping is necessary because Seaborn expects the data in this structure to plot different groups and categories correctly.
#
# One the 'all_data' DataFrame is loaded, Seaborn is ready for plotting.

# %%
# 'Dataset' column added to each DataFrame
data_corona['Dataset'] = 'SARS-CoV-2'
data_human['Dataset'] = 'Homo Sapiens'
data_influenza['Dataset'] = 'Influenza A'

# Combine into long format
all_data = pd.concat([
    data_corona.melt(
        id_vars=['Dataset'],
        value_vars=['len_H1', 'len_H2', 'len_H3'],
        var_name='CDR',
        value_name='Length'
    ),
    data_human.melt(
        id_vars=['Dataset'],
        value_vars=['len_H1', 'len_H2', 'len_H3'],
        var_name='CDR',
        value_name='Length'
    ),
    data_influenza.melt(
        id_vars=['Dataset'],
        value_vars=['len_H1', 'len_H2', 'len_H3'],
        var_name='CDR',
        value_name='Length'
    )
], ignore_index=True)

# %%
sns.boxplot(
    data=all_data,
    x='CDR',
    y='Length',
    hue='Dataset',
    palette={
        'SARS-CoV-2': '#9509BB',
        'Homo Sapiens': '#FFCF01',
        'Influenza A': '#FF474B' 
    }
)
# Out:
# <Axes: xlabel='CDR', ylabel='Length'>

# %% [markdown]
# Based on this plot and the histograms, it is immediately noticeable that CDR H3 is longer than the other CDRs in the heavy chain, including showing greater variability. Among the CDR H3 regions, Influenza A displays the longest sequences overall. However, when looking at the histogram, it becomes clear that the frequency of these long sequences is very low, suggesting that the significance of this potential outlier still needs to be evaluated. In contrast to H3, CDR H1 and H2 appear to have more similar length distributions, with only a few outliers.

# %% [markdown]
# Because CDR lengths are often not normally distributed and can include outliers, as seen in the boxplot, this step calculates the median length for each CDR region and dataset rather than the mean, since the median is less sensitive to extreme values. The code groups all sequences by CDR type and organism, computes the median length in each group, and visualizes these medians in a bar plot. This makes it easier to compare the typical lengths of each CDR region across datasets in a clear and robust way.

# %%
# calculating median of each group
median_lengths = all_data.groupby(['CDR', 'Dataset'])['Length'].median().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(
    data=median_lengths,
    x="CDR",
    y="Length",
    hue="Dataset",
    palette = {'SARS-CoV-2': '#9509BB', 'Homo Sapiens': '#FFCF01', 'Influenza A': '#FF474B'}
)
plt.title("Median length of CDRs per organsim")
plt.ylabel("median of CDR length")
plt.xlabel("CDR")
plt.tight_layout()
plt.show()

# %% [markdown]
# In order to get a brief overview, the data is reshaped into a long format so each row represents a single CDR measurement with its source label. Descriptive statistics, including minimum, maximum, mean, standard deviation, and range, are computed for each CDR type in each organism group, allowing an overview of how CDR lengths differ across datasets.

# %%
import pandas as pd

# 1) Read TSV files
sars_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\corona_cdr_seq.tsv", sep="\t")
human_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\human_cdr_seq.tsv", sep="\t")
influenza_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\influenza_cdr_seq.tsv", sep="\t")

# 2) Combine all into one DataFrame
def extract_lengths(df, label):
    return pd.DataFrame({
        "CDR_H1_len": df["CDR_H1"].str.len(),
        "CDR_H2_len": df["CDR_H2"].str.len(),
        "CDR_H3_len": df["CDR_H3"].str.len(),
        "Source": label
    })

df_all = pd.concat([
    extract_lengths(sars_df, "SARS"),
    extract_lengths(human_df, "Human"),
    extract_lengths(influenza_df, "Flu")
], ignore_index=True)

# 3) Transform into long format
lengths_long = df_all.melt(
    id_vars="Source",
    value_vars=["CDR_H1_len", "CDR_H2_len", "CDR_H3_len"],
    var_name="CDR",
    value_name="Length"
)

# Clean up the CDR column to just H1, H2, H3
lengths_long["CDR"] = lengths_long["CDR"].str.replace("_len", "")

# 4) Group by CDR and organism to compute descriptive statistics
stats = lengths_long.groupby(["Source", "CDR"])["Length"].agg(
    Min="min",
    Max="max",
    Mean="mean",
    Std="std",
    Range=lambda x: x.max() - x.min()
)

# 5) Print the results
print("Length statistics per organism and CDR:")
print(stats)
# Out:
# Length statistics per organism and CDR:
#                Min  Max       Mean       Std  Range
# Source CDR
# Flu    CDR_H1    4   12   7.806122  1.289595      8
#        CDR_H2    2    8   5.612245  0.712664      6
#        CDR_H3    7   26  17.112245  3.976432     19
# Human  CDR_H1    4    9   7.159091  0.557974      5
#        CDR_H2    4   10   5.906566  0.602827      6
#        CDR_H3    4   22  11.446970  3.419929     18
# SARS   CDR_H1    4    9   7.145610  0.597021      5
#        CDR_H2    5   10   5.674518  0.659247      5
#        CDR_H3    5   24  13.194861  3.805707     19

# %% [markdown]
# This code performs a hierarchical cluster analysis based on the mean lengths of the CDRs. The data is organized into a table containing the mean CDR lengths per organism and region. The table is then reshaped so each organism is represented by a vector of mean lengths across the three CDRs. Using Ward’s linkage method, a hierarchical clustering is computed to group the organisms based on similarity in their CDR length profiles. Finally, the resulting dendrogram visually represents these relationships by displaying clusters and the distances between them.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# Your data as a DataFrame (recreate from your table)
data = {
    ('Flu', 'CDR_H1'): [7.806122],
    ('Flu', 'CDR_H2'): [5.612245],
    ('Flu', 'CDR_H3'): [17.112245],
    ('Human', 'CDR_H1'): [7.159091],
    ('Human', 'CDR_H2'): [5.906566],
    ('Human', 'CDR_H3'): [11.446970],
    ('SARS', 'CDR_H1'): [7.145610],
    ('SARS', 'CDR_H2'): [5.674518],
    ('SARS', 'CDR_H3'): [13.194861],
}

# Convert to multiindex dataframe
df = pd.DataFrame(data).T.reset_index()
df.columns = ['Organism', 'CDR', 'MeanLength']

# Pivot to have CDR types as columns, organisms as rows
df_pivot = df.pivot(index='Organism', columns='CDR', values='MeanLength')


# Hierarchical clustering on the means
linkage_matrix = linkage(df_pivot, method='ward')

# Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(linkage_matrix, labels=df_pivot.index)
plt.title('Hierarchical Clustering of Organisms by Mean CDR Lengths')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# The dendrogram shows that Human and SARS cluster closely together, reflecting their similar mean CDR lengths across all three regions, especially in CDR H3 where both have shorter average lengths compared to Flu. Flu forms a separate cluster, which indicates its CDR length profile is distinct, particularly due to its much longer and more variable CDR H3 region. This shows that Flu antibodies differ substantially in their CDR characteristics.

# %% [markdown]
# ### Statistical hypothesis testing

# %% [markdown]
# This code loads CDR sequence data for SARS-CoV-2, human, and influenza antibodies and extracts the lengths of the heavy-chain CDR1, CDR2, and CDR3 regions.
# The code above showed some variances regarding the distribution of the lengths. However, some lengths are minimally represented. To test whether the variances of these lengths differ significantly between CDR types, it is helpful to conduct a statistical hypothesis test.
# In this case, the Levene’s test analyzes homogeneity of variance. Levene’s test calculates the distance of each observation from its group mean and tests whether the spread of those distances is the same across groups.
# A significant result (p < 0.05) indicates that the variability of lengths is different across the CDRs. Finally, a boxplot visualizes the distributions and the spread of the CDR lengths for easier comparison.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import levene

# 1) Load the data
sars_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\corona_cdr_seq.tsv", sep="\t")
human_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\human_cdr_seq.tsv", sep="\t")
influenza_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\influenza_cdr_seq.tsv", sep="\t")

# 2) Extract CDR lengths
def extract_lengths(df, label):
    return pd.DataFrame({
        "CDR_H1_len": df["CDR_H1"].str.len(),
        "CDR_H2_len": df["CDR_H2"].str.len(),
        "CDR_H3_len": df["CDR_H3"].str.len(),
        "Source": label
    })

df_all = pd.concat([
    extract_lengths(sars_df, "SARS"),
    extract_lengths(human_df, "Human"),
    extract_lengths(influenza_df, "Flu")
], ignore_index=True)

# 3) Reshape data into long format for easier plotting
lengths_long = df_all.melt(
    id_vars="Source",
    value_vars=["CDR_H1_len", "CDR_H2_len", "CDR_H3_len"],
    var_name="CDR",
    value_name="Length"
)

# Simplify CDR column names
lengths_long["CDR"] = lengths_long["CDR"].str.replace("_len", "")

# 4) Levene’s test for each organism: do H1, H2, and H3 have equal variances?
print("Levene tests per organism (H1 vs H2 vs H3):\n")
for organism in lengths_long["Source"].unique():
    sub_df = lengths_long[lengths_long["Source"] == organism]
    len_H1 = sub_df[sub_df["CDR"] == "CDR_H1"]["Length"].dropna()
    len_H2 = sub_df[sub_df["CDR"] == "CDR_H2"]["Length"].dropna()
    len_H3 = sub_df[sub_df["CDR"] == "CDR_H3"]["Length"].dropna()
    stat, p = levene(len_H1, len_H2, len_H3)
    print(f"{organism}: W = {stat:.3f}, p = {p:.3g}")
    if p < 0.05:
        print("Significant differences in variance!\n")
    else:
        print("No significant differences.\n")
# Out:
# Levene tests per organism (H1 vs H2 vs H3):
#
# SARS: W = 730.570, p = 6.32e-218
# Significant differences in variance!
#
# Human: W = 467.904, p = 1.68e-150
# Significant differences in variance!
#
# Flu: W = 86.894, p = 2.58e-30
# Significant differences in variance!

# %% [markdown]
# Levene’s test showed highly significant differences in variance across CDR_H1, CDR_H2, and CDR_H3 in all organisms analyzed. This indicates that the variability of CDR lengths is not uniform and that some CDRs fluctuate in length much more than others.

# %% [markdown]
# Since Levene’s test checks differences in variances and does not say anything about differences in the median or mean, Kruskal-Wallis and Mann-Whitney test is used to check differences in systematical tendency.
# The aim is to answer the question if the medians differ between the three organisms.
# In this code, the CDR_H3 sequences from all datasets are loaded and their lengths computed. Then the Kruskal-Wallis test is used to analyse whether at least one group differs significantly in median length. If significant, a pairwise Mann-Whitney U-test is performed to find out which pairs differ.

# %%
import pandas as pd
from scipy.stats import kruskal, mannwhitneyu
import seaborn as sns
import matplotlib.pyplot as plt

# 1) Read TSV files
sars_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\corona_cdr_seq.tsv", sep="\t")
human_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\human_cdr_seq.tsv", sep="\t")
influenza_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\influenza_cdr_seq.tsv", sep="\t")

# 2) Extract CDR_H3 lengths into a combined DataFrame
def extract_lengths(df, label):
    return pd.DataFrame({
        "CDR_H3_len": df["CDR_H3"].str.len(),
        "Source": label
    })

df_all = pd.concat([
    extract_lengths(sars_df, "SARS"),
    extract_lengths(human_df, "Human"),
    extract_lengths(influenza_df, "Flu")
], ignore_index=True)

# 3) Prepare lists of lengths per organism
h3_flu = df_all[df_all["Source"] == "Flu"]["CDR_H3_len"].dropna()
h3_human = df_all[df_all["Source"] == "Human"]["CDR_H3_len"].dropna()
h3_sars = df_all[df_all["Source"] == "SARS"]["CDR_H3_len"].dropna()

# 4) Kruskal-Wallis test for differences in medians across all groups
stat, p = kruskal(h3_flu, h3_human, h3_sars)
print(f"Kruskal-Wallis test: H = {stat:.3f}, p = {p:.3g}")

if p < 0.05:
    print("Significant difference in median lengths between groups!")
else:
    print("No significant difference in median lengths.")

# 5) Post-hoc pairwise Mann-Whitney U-tests
print("\nPost-hoc pairwise Mann-Whitney U-tests:")

pairs = [
    ("Flu", h3_flu, "Human", h3_human),
    ("Flu", h3_flu, "SARS", h3_sars),
    ("Human", h3_human, "SARS", h3_sars)
]

for (name1, group1, name2, group2) in pairs:
    u_stat, p_mw = mannwhitneyu(group1, group2, alternative='two-sided')
    print(f"{name1} vs {name2}: U = {u_stat}, p = {p_mw:.3g}")
# Out:
# Kruskal-Wallis test: H = 137.346, p = 1.5e-30
# Significant difference in median lengths between groups!
#
# Post-hoc pairwise Mann-Whitney U-tests:
# Flu vs Human: U = 33197.5, p = 7.77e-28
# Flu vs SARS: U = 34645.5, p = 9.44e-16
# Human vs SARS: U = 68812.5, p = 7.58e-11

# %% [markdown]
# The Kruskal-Wallis test showed a highly significant difference in the median CDR_H3 lengths among the three organisms  p < 0,05.
# The post-hoc Mann-Whitney U-tests confirmed that all pairs of groups differ significantly from each other

# %% [markdown]
# CDR_H1 and CDR_H2 are also tested in following code

# %%
import pandas as pd
from scipy.stats import kruskal, mannwhitneyu
import seaborn as sns
import matplotlib.pyplot as plt

# 1) Load TSV files
sars_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\corona_cdr_seq.tsv", sep="\t")
human_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\human_cdr_seq.tsv", sep="\t")
influenza_df = pd.read_csv(r"C:\Users\clara\group04-team02\generated\cdrs\seq\influenza_cdr_seq.tsv", sep="\t")

# 2) Extract lengths of CDR_H1 and CDR_H2
def extract_lengths(df, label):
    return pd.DataFrame({
        "CDR_H1_len": df["CDR_H1"].str.len(),
        "CDR_H2_len": df["CDR_H2"].str.len(),
        "Source": label
    })

df_all = pd.concat([
    extract_lengths(sars_df, "SARS"),
    extract_lengths(human_df, "Human"),
    extract_lengths(influenza_df, "Flu")
], ignore_index=True)

# 3) Prepare lists of lengths per group
# CDR_H1
h1_flu = df_all[df_all["Source"] == "Flu"]["CDR_H1_len"].dropna()
h1_human = df_all[df_all["Source"] == "Human"]["CDR_H1_len"].dropna()
h1_sars = df_all[df_all["Source"] == "SARS"]["CDR_H1_len"].dropna()

# CDR_H2
h2_flu = df_all[df_all["Source"] == "Flu"]["CDR_H2_len"].dropna()
h2_human = df_all[df_all["Source"] == "Human"]["CDR_H2_len"].dropna()
h2_sars = df_all[df_all["Source"] == "SARS"]["CDR_H2_len"].dropna()

# 4) Kruskal-Wallis test for CDR_H1
print("\nCDR_H1 Kruskal-Wallis test:")
stat_h1, p_h1 = kruskal(h1_flu, h1_human, h1_sars)
print(f"H = {stat_h1:.3f}, p = {p_h1:.3g}")

if p_h1 < 0.05:
    print("Significant difference in median lengths between groups for CDR_H1")
else:
    print("No significant difference in median lengths for CDR_H1.")

# 5) Post-hoc Mann-Whitney U-tests for CDR_H1
print("\nPost-hoc pairwise Mann-Whitney U-tests for CDR_H1:")

pairs_h1 = [
    ("Flu", h1_flu, "Human", h1_human),
    ("Flu", h1_flu, "SARS", h1_sars),
    ("Human", h1_human, "SARS", h1_sars)
]

for (name1, group1, name2, group2) in pairs_h1:
    u_stat, p_mw = mannwhitneyu(group1, group2, alternative='two-sided')
    print(f"{name1} vs {name2}: U = {u_stat}, p = {p_mw:.3g}")

# 6) Kruskal-Wallis test for CDR_H2
print("\nCDR_H2 Kruskal-Wallis test:")
stat_h2, p_h2 = kruskal(h2_flu, h2_human, h2_sars)
print(f"H = {stat_h2:.3f}, p = {p_h2:.3g}")

if p_h2 < 0.05:
    print("Significant difference in median lengths between groups for CDR_H2!")
else:
    print("No significant difference in median lengths for CDR_H2.")

# 7) Post-hoc Mann-Whitney U-tests for CDR_H2
print("\nPost-hoc pairwise Mann-Whitney U-tests for CDR_H2:")

pairs_h2 = [
    ("Flu", h2_flu, "Human", h2_human),
    ("Flu", h2_flu, "SARS", h2_sars),
    ("Human", h2_human, "SARS", h2_sars)
]

for (name1, group1, name2, group2) in pairs_h2:
    u_stat, p_mw = mannwhitneyu(group1, group2, alternative='two-sided')
    print(f"{name1} vs {name2}: U = {u_stat}, p = {p_mw:.3g}")
# Out:
# CDR_H1 Kruskal-Wallis test:
# H = 70.909, p = 4e-16
# Significant difference in median lengths between groups for CDR_H1
#
# Post-hoc pairwise Mann-Whitney U-tests for CDR_H1:
# Flu vs Human: U = 25358.5, p = 1.25e-12
# Flu vs SARS: U = 30052.5, p = 1.27e-14
# Human vs SARS: U = 93628.0, p = 0.548
#
# CDR_H2 Kruskal-Wallis test:
# H = 49.616, p = 1.68e-11
# Significant difference in median lengths between groups for CDR_H2!
#
# Post-hoc pairwise Mann-Whitney U-tests for CDR_H2:
# Flu vs Human: U = 14818.0, p = 2.37e-06
# Flu vs SARS: U = 22230.0, p = 0.603
# Human vs SARS: U = 112203.0, p = 2.2e-11

# %% [markdown]
# CDR_H1
# The Flu sequences have median CDR_H1 lengths distinctly different from both Human and SARS, but Human and SARS do not differ significantly from each other.
#
# CDR_H2
# Human sequences differ significantly from both Flu and SARS.
# Flu and SARS do not differ significantly from each other.
#
# These findings indicate that CDR length distributions vary systematically between the organisms, but the patterns are not uniform across different CDRs.
