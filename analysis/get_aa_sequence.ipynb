# %%
from pathlib import Path
import argparse
from pandas import read_csv, DataFrame, concat
from Bio.PDB import PDBParser
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# %%
from Bio.PDB import PDBList
from pathlib import Path

import pandas as pd

pdbl = PDBList()
output_dir = Path("pdb_files")
output_dir.mkdir(exist_ok=True)

# IDs bereinigen und eindeutige Liste erstellen
pdb_ids = df_clean["pdb"].str.lower().unique()

for pdb_id in pdb_ids:
    try:
        pdbl.retrieve_pdb_file(pdb_id, pdir=output_dir, file_format="pdb")
    except Exception as e:
        print(f"Fehler beim Herunterladen von {pdb_id}: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       2 from pathlib import Path
#       4 import pandas as pd
# ----> 6 df_clean= df_clean
#       9 pdbl = PDBList()
#      10 output_dir = Path("pdb_files")
#
# NameError: name 'df_clean' is not defined

# %%
#from Bio.PDB import PDBParser

#parser = PDBParser(QUIET=True)
#structure = parser.get_structure("8uzp", "8uzp.pdb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from Bio.PDB import PDBParser
#       3 parser = PDBParser(QUIET=True)
# ----> 4 structure = parser.get_structure("8uzp", "8uzp.pdb")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\Bio\PDB\PDBParser.py:85, in PDBParser.get_structure(self, id, file)
#      82 # Make a StructureBuilder instance (pass id of structure as parameter)
#      83 self.structure_builder.init_structure(id)
# ---> 85 with as_handle(file) as handle:
#      86     lines = handle.readlines()
#      87     if not lines:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from Bio.PDB import PDBParser
#       3 parser = PDBParser(QUIET=True)
# ----> 4 structure = parser.get_structure("8uzp", "8uzp.pdb")
#       6 vh_seq = get_vhvl_seq(structure, "H")  # Für VH
#       7 vl_seq = get_vhvl_seq(structure, "L")  # Für VL
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\Bio\PDB\PDBParser.py:85, in PDBParser.get_structure(self, id, file)
#      82 # Make a StructureBuilder instance (pass id of structure as parameter)
#      83 self.structure_builder.init_structure(id)
# ---> 85 with as_handle(file) as handle:
#      86     lines = handle.readlines()
#      87     if not lines:
#
# ...
