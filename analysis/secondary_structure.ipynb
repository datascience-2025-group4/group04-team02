# %%
# use psipred to predict secondary structure
import DSSP 
from Bio.PDB import PDBParser
# from Bio.PDB.DSSP import DSSP
# from Bio.PDB.DSSP import dssp_dict_from_pdb_file
from Bio.PDB.DSSP import dssp_dict_from_pdb_file
from Bio.PDB import PDBParser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # use psipred to predict secondary structure
# ----> 2 import DSSP
#       3 from Bio.PDB import PDBParser
#       4 # from Bio.PDB.DSSP import DSSP
#       5 # from Bio.PDB.DSSP import dssp_dict_from_pdb_file
#
# ModuleNotFoundError: No module named 'DSSP'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
